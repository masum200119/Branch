# %%
import os
import torch
import torch.nn as nn
from torch.utils.data import DataLoader
from torchvision import datasets, transforms
from torchvision.models import alexnet, AlexNet_Weights
from torch.optim import AdamW
import matplotlib.pyplot as plt
from tqdm import tqdm
from sklearn.metrics import (accuracy_score, classification_report, 
                           confusion_matrix, roc_curve, auc,
                           precision_recall_curve, average_precision_score, f1_score,
                           precision_score, recall_score)
from sklearn.preprocessing import label_binarize
import numpy as np
from itertools import cycle
import random
import seaborn as sns

# Configuration
CONFIG = {
    "dataset_path": r"E:\\Symposiam\\CC",
    "image_size": 224,
    "batch_size": 16,
    "num_epochs": 20,
    "learning_rate": 5e-5,
    "weight_decay": 0.01,
    "dropout_rate": 0.5,  # AlexNet classifier already uses Dropout(0.5)
    "seed": 42
}

# Set random seeds for reproducibility
def set_seed(seed):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

set_seed(CONFIG["seed"])

# Device setup
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

# Data preparation
def prepare_data():
    # Common transform without augmentation
    base_transform = transforms.Compose([
        # If images are grayscale, uncomment to expand to 3 channels
        # transforms.Grayscale(num_output_channels=3),
        transforms.Resize((CONFIG["image_size"], CONFIG["image_size"])),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
    ])

    # Augmentation for training
    train_transform = transforms.Compose([
        # transforms.Grayscale(num_output_channels=3),  # uncomment if inputs are grayscale
        transforms.Resize((CONFIG["image_size"], CONFIG["image_size"])),
        transforms.RandomHorizontalFlip(),
        transforms.RandomVerticalFlip(),
        transforms.RandomRotation(30),
        transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.1),
        transforms.RandomAffine(degrees=0, translate=(0.1, 0.1)),
        transforms.RandomResizedCrop(CONFIG["image_size"], scale=(0.8, 1.0)),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
        transforms.RandomErasing(p=0.1, scale=(0.02, 0.1), ratio=(0.3, 3.3))
    ])

    # Load datasets
    train_dataset = datasets.ImageFolder(os.path.join(CONFIG["dataset_path"], "train"), transform=train_transform)
    val_dataset = datasets.ImageFolder(os.path.join(CONFIG["dataset_path"], "val"), transform=base_transform)
    test_dataset = datasets.ImageFolder(os.path.join(CONFIG["dataset_path"], "test"), transform=base_transform)

    print("\nClass distribution:")
    print(f"Train: {np.bincount([y for _, y in train_dataset])}")
    print(f"Val: {np.bincount([y for _, y in val_dataset])}")
    print(f"Test: {np.bincount([y for _, y in test_dataset])}")

    return (
        DataLoader(train_dataset, batch_size=CONFIG["batch_size"], shuffle=True, num_workers=2, pin_memory=True),
        DataLoader(val_dataset, batch_size=CONFIG["batch_size"], shuffle=False, num_workers=2, pin_memory=True),
        DataLoader(test_dataset, batch_size=CONFIG["batch_size"], shuffle=False, num_workers=2, pin_memory=True),
        train_dataset.classes
    )

# Model setup (AlexNet)
def setup_model(num_classes):
    # Load pretrained AlexNet
    weights = AlexNet_Weights.IMAGENET1K_V1
    model = alexnet(weights=weights)

    # Replace final classifier layer while retaining Dropout layers
    # AlexNet classifier: [Dropout, Linear(9216->4096), ReLU, Dropout, Linear(4096->4096), ReLU, Linear(4096->1000)]
    in_features = model.classifier[6].in_features
    model.classifier[6] = nn.Linear(in_features, num_classes)

    # Optionally add extra dropout in front (kept default architecture)

    # Freeze all layers first
    for p in model.parameters():
        p.requires_grad = False

    # Unfreeze last conv block(s) + classifier for fine-tuning
    # AlexNet features is a Sequential of conv/relu/pool; unfreeze last 2 conv blocks
    for p in model.features[8:].parameters():  # layers after index 8 (conv5)
        p.requires_grad = True

    for p in model.classifier.parameters():
        p.requires_grad = True

    return model.to(device)

# Training loop
def train_model(model, train_loader, val_loader):
    optimizer = AdamW(
        filter(lambda p: p.requires_grad, model.parameters()),
        lr=CONFIG["learning_rate"],
        weight_decay=CONFIG["weight_decay"]
    )
    criterion = nn.CrossEntropyLoss()
    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
        optimizer, mode='max', factor=0.1, patience=3, verbose=True
    )

    history = {
        'train_loss': [], 'val_loss': [], 'train_acc': [], 'val_acc': [],
        'train_precision': [], 'val_precision': [], 'train_recall': [], 'val_recall': [],
        'train_f1': [], 'val_f1': [], 'learning_rates': []
    }

    for epoch in range(CONFIG["num_epochs"]):
        model.train()
        train_loss, train_preds, train_labels = 0.0, [], []

        for inputs, labels in tqdm(train_loader, desc=f"Epoch {epoch+1}/{CONFIG['num_epochs']} - Training"):
            inputs, labels = inputs.to(device), labels.to(device)
            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            train_loss += loss.item()
            train_preds.extend(torch.argmax(outputs, dim=1).cpu().numpy())
            train_labels.extend(labels.cpu().numpy())

        train_loss /= len(train_loader)
        train_acc = accuracy_score(train_labels, train_preds)
        train_precision = precision_score(train_labels, train_preds, average='weighted', zero_division=0)
        train_recall = recall_score(train_labels, train_preds, average='weighted', zero_division=0)
        train_f1 = f1_score(train_labels, train_preds, average='weighted', zero_division=0)

        # Validation
        val_loss, val_preds, val_labels = evaluate_model(model, val_loader, criterion)
        val_acc = accuracy_score(val_labels, val_preds)
        val_precision = precision_score(val_labels, val_preds, average='weighted', zero_division=0)
        val_recall = recall_score(val_labels, val_preds, average='weighted', zero_division=0)
        val_f1 = f1_score(val_labels, val_preds, average='weighted', zero_division=0)

        # Store metrics
        history['train_loss'].append(train_loss)
        history['val_loss'].append(val_loss)
        history['train_acc'].append(train_acc)
        history['val_acc'].append(val_acc)
        history['train_precision'].append(train_precision)
        history['val_precision'].append(val_precision)
        history['train_recall'].append(train_recall)
        history['val_recall'].append(val_recall)
        history['train_f1'].append(train_f1)
        history['val_f1'].append(val_f1)
        history['learning_rates'].append(optimizer.param_groups[0]['lr'])

        scheduler.step(val_acc)

        print(f"Epoch {epoch+1}: Train Loss: {train_loss:.4f} | Val Loss: {val_loss:.4f} | Train Acc: {train_acc:.4f} | Val Acc: {val_acc:.4f}")
        print(f"         Train F1: {train_f1:.4f} | Val F1: {val_f1:.4f} | LR: {optimizer.param_groups[0]['lr']:.6f}")

    return history, val_preds, val_labels


def evaluate_model(model, loader, criterion):
    model.eval()
    total_loss, preds, labels = 0.0, [], []
    with torch.no_grad():
        for inputs, labels_batch in tqdm(loader, desc="Evaluating"):
            inputs, labels_batch = inputs.to(device), labels_batch.to(device)
            outputs = model(inputs)
            loss = criterion(outputs, labels_batch)
            total_loss += loss.item()
            preds.extend(torch.argmax(outputs, dim=1).cpu().numpy())
            labels.extend(labels_batch.cpu().numpy())

    return total_loss / len(loader), preds, labels


def get_predictions_with_probabilities(model, loader):
    model.eval()
    all_preds = []
    all_labels = []
    all_probs = []

    with torch.no_grad():
        for inputs, labels in tqdm(loader, desc="Getting predictions with probabilities"):
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            probs = torch.softmax(outputs, dim=1)

            all_preds.extend(torch.argmax(outputs, dim=1).cpu().numpy())
            all_labels.extend(labels.cpu().numpy())
            all_probs.extend(probs.cpu().numpy())

    return np.array(all_preds), np.array(all_labels), np.array(all_probs)


def plot_comprehensive_results(history, class_names, val_preds, val_labels, test_preds=None, test_labels=None, test_probs=None):
    # Create a comprehensive figure with multiple subplots
    fig = plt.figure(figsize=(25, 30))

    # 1. Training History - Loss and Accuracy
    plt.subplot(5, 4, 1)
    plt.plot(history['train_loss'], label='Training Loss', linewidth=2)
    plt.plot(history['val_loss'], label='Validation Loss', linewidth=2)
    plt.title('Training and Validation Loss', fontsize=14)
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid(True, alpha=0.3)

    plt.subplot(5, 4, 2)
    plt.plot(history['train_acc'], label='Training Accuracy', linewidth=2)
    plt.plot(history['val_acc'], label='Validation Accuracy', linewidth=2)
    plt.title('Training and Validation Accuracy', fontsize=14)
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.grid(True, alpha=0.3)

    # 2. Precision, Recall, and F1-Score
    plt.subplot(5, 4, 3)
    plt.plot(history['train_precision'], label='Training Precision', linewidth=2)
    plt.plot(history['val_precision'], label='Validation Precision', linewidth=2)
    plt.title('Training and Validation Precision', fontsize=14)
    plt.xlabel('Epoch')
    plt.ylabel('Precision')
    plt.legend()
    plt.grid(True, alpha=0.3)

    plt.subplot(5, 4, 4)
    plt.plot(history['train_recall'], label='Training Recall', linewidth=2)
    plt.plot(history['val_recall'], label='Validation Recall', linewidth=2)
    plt.title('Training and Validation Recall', fontsize=14)
    plt.xlabel('Epoch')
    plt.ylabel('Recall')
    plt.legend()
    plt.grid(True, alpha=0.3)

    plt.subplot(5, 4, 5)
    plt.plot(history['train_f1'], label='Training F1-Score', linewidth=2)
    plt.plot(history['val_f1'], label='Validation F1-Score', linewidth=2)
    plt.title('Training and Validation F1-Score', fontsize=14)
    plt.xlabel('Epoch')
    plt.ylabel('F1-Score')
    plt.legend()
    plt.grid(True, alpha=0.3)

    # 3. Learning Rate Schedule
    plt.subplot(5, 4, 6)
    plt.plot(history['learning_rates'], linewidth=2)
    plt.title('Learning Rate Schedule', fontsize=14)
    plt.xlabel('Epoch')
    plt.ylabel('Learning Rate')
    plt.yscale('log')
    plt.grid(True, alpha=0.3)

    # 4. Confusion Matrix for Validation
    plt.subplot(5, 4, 7)
    cm_val = confusion_matrix(val_labels, val_preds)
    sns.heatmap(cm_val, annot=True, fmt='d', cmap='Blues', 
                xticklabels=class_names, yticklabels=class_names)
    plt.title('Validation Confusion Matrix', fontsize=14)
    plt.xlabel('Predicted')
    plt.ylabel('Actual')

    # 5. Confusion Matrix for Test (if available)
    if test_preds is not None and test_labels is not None:
        plt.subplot(5, 4, 8)
        cm_test = confusion_matrix(test_labels, test_preds)
        sns.heatmap(cm_test, annot=True, fmt='d', cmap='Greens', 
                    xticklabels=class_names, yticklabels=class_names)
        plt.title('Test Confusion Matrix', fontsize=14)
        plt.xlabel('Predicted')
        plt.ylabel('Actual')

    # 6. ROC Curves (if test probabilities available)
    if test_probs is not None and test_labels is not None:
        plt.subplot(5, 4, 9)
        n_classes = len(class_names)
        test_labels_bin = label_binarize(test_labels, classes=range(n_classes))

        if n_classes == 2:
            fpr, tpr, _ = roc_curve(test_labels_bin, test_probs[:, 1])
            roc_auc = auc(fpr, tpr)
            plt.plot(fpr, tpr, label=f'ROC curve (AUC = {roc_auc:.2f})', linewidth=2)
        else:
            for i in range(n_classes):
                fpr, tpr, _ = roc_curve(test_labels_bin[:, i], test_probs[:, i])
                roc_auc = auc(fpr, tpr)
                plt.plot(fpr, tpr, lw=2, label=f'ROC class {class_names[i]} (AUC={roc_auc:.2f})')

        plt.plot([0, 1], [0, 1], 'k--', lw=2)
        plt.xlim([0.0, 1.0])
        plt.ylim([0.0, 1.05])
        plt.xlabel('False Positive Rate')
        plt.ylabel('True Positive Rate')
        plt.title('ROC Curves', fontsize=14)
        plt.legend(loc="lower right")
        plt.grid(True, alpha=0.3)

    # 7. Precision-Recall Curves
    if test_probs is not None and test_labels is not None:
        plt.subplot(5, 4, 10)
        n_classes = len(class_names)
        test_labels_bin = label_binarize(test_labels, classes=range(n_classes))

        if n_classes == 2:
            precision, recall, _ = precision_recall_curve(test_labels_bin, test_probs[:, 1])
            avg_precision = average_precision_score(test_labels_bin, test_probs[:, 1])
            plt.plot(recall, precision, label=f'PR curve (AP = {avg_precision:.2f})', linewidth=2)
        else:
            for i in range(n_classes):
                precision, recall, _ = precision_recall_curve(test_labels_bin[:, i], test_probs[:, i])
                avg_precision = average_precision_score(test_labels_bin[:, i], test_probs[:, i])
                plt.plot(recall, precision, lw=2, label=f'PR class {class_names[i]} (AP={avg_precision:.2f})')

        plt.xlabel('Recall')
        plt.ylabel('Precision')
        plt.title('Precision-Recall Curves', fontsize=14)
        plt.legend()
        plt.grid(True, alpha=0.3)

    # 8. Class-wise Performance Metrics
    if test_preds is not None and test_labels is not None:
        plt.subplot(5, 4, 11)
        report = classification_report(test_labels, test_preds, target_names=class_names, output_dict=True)

        metrics = ['precision', 'recall', 'f1-score']
        class_metrics = {metric: [] for metric in metrics}

        for class_name in class_names:
            for metric in metrics:
                class_metrics[metric].append(report[class_name][metric])

        x = np.arange(len(class_names))
        width = 0.25

        for i, metric in enumerate(metrics):
            plt.bar(x + i*width, class_metrics[metric], width, label=metric.capitalize())

        plt.xlabel('Classes')
        plt.ylabel('Score')
        plt.title('Class-wise Performance Metrics', fontsize=14)
        plt.xticks(x + width, class_names, rotation=45)
        plt.legend()
        plt.grid(True, alpha=0.3)

    # 9. Training Progress Summary
    plt.subplot(5, 4, 12)
    epochs = range(1, len(history['train_loss']) + 1)
    plt.plot(epochs, history['train_loss'], '-', label='Training Loss', linewidth=2)
    plt.plot(epochs, history['val_loss'], '-', label='Validation Loss', linewidth=2)
    plt.plot(epochs, [1-acc for acc in history['train_acc']], '--', label='Training Error', linewidth=2)
    plt.plot(epochs, [1-acc for acc in history['val_acc']], '--', label='Validation Error', linewidth=2)
    plt.title('Training Progress: Loss and Error', fontsize=14)
    plt.xlabel('Epoch')
    plt.ylabel('Loss / Error')
    plt.legend()
    plt.grid(True, alpha=0.3)

    # 10. Validation Accuracy vs Loss
    plt.subplot(5, 4, 13)
    plt.scatter(history['val_loss'], history['val_acc'], c=range(len(history['val_loss'])), s=50)
    plt.xlabel('Validation Loss')
    plt.ylabel('Validation Accuracy')
    plt.title('Validation Accuracy vs Loss', fontsize=14)
    plt.colorbar(label='Epoch')
    plt.grid(True, alpha=0.3)

    # 11. Learning Rate vs Validation Accuracy
    plt.subplot(5, 4, 14)
    plt.semilogx(history['learning_rates'], history['val_acc'], 'o-', linewidth=2, markersize=4)
    plt.xlabel('Learning Rate')
    plt.ylabel('Validation Accuracy')
    plt.title('Learning Rate vs Validation Accuracy', fontsize=14)
    plt.grid(True, alpha=0.3)

    # 12. Training Speed (Loss Reduction Rate)
    plt.subplot(5, 4, 15)
    loss_reduction = []
    for i in range(1, len(history['train_loss'])):
        reduction = history['train_loss'][i-1] - history['train_loss'][i]
        loss_reduction.append(reduction)

    plt.plot(range(2, len(history['train_loss']) + 1), loss_reduction, '-', linewidth=2)
    plt.xlabel('Epoch')
    plt.ylabel('Loss Reduction')
    plt.title('Training Loss Reduction Rate', fontsize=14)
    plt.axhline(y=0, linestyle='--', alpha=0.5)
    plt.grid(True, alpha=0.3)

    # 13. Overfitting Analysis
    plt.subplot(5, 4, 16)
    overfitting_gap = [train_acc - val_acc for train_acc, val_acc in zip(history['train_acc'], history['val_acc'])]
    plt.plot(range(1, len(overfitting_gap) + 1), overfitting_gap, linewidth=2)
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy Gap (Train - Val)')
    plt.title('Overfitting Analysis', fontsize=14)
    plt.axhline(y=0, linestyle='--', alpha=0.5)
    plt.grid(True, alpha=0.3)

    # 14. Metric Correlation Matrix
    plt.subplot(5, 4, 17)
    metrics_df = {
        'Train Loss': history['train_loss'],
        'Val Loss': history['val_loss'],
        'Train Acc': history['train_acc'],
        'Val Acc': history['val_acc'],
        'Train F1': history['train_f1'],
        'Val F1': history['val_f1']
    }
    correlation_matrix = np.corrcoef([metrics_df[key] for key in metrics_df.keys()])
    sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', center=0,
                xticklabels=list(metrics_df.keys()), yticklabels=list(metrics_df.keys()))
    plt.title('Metric Correlation Matrix', fontsize=14)

    # 15. Per-class Accuracy (if available)
    if test_preds is not None and test_labels is not None:
        plt.subplot(5, 4, 18)
        per_class_acc = []
        for i, class_name in enumerate(class_names):
            class_mask = np.array(test_labels) == i
            if np.sum(class_mask) > 0:
                class_acc = accuracy_score(np.array(test_labels)[class_mask], 
                                         np.array(test_preds)[class_mask])
                per_class_acc.append(class_acc)
            else:
                per_class_acc.append(0)

        plt.bar(range(len(class_names)), per_class_acc)
        plt.xlabel('Classes')
        plt.ylabel('Accuracy')
        plt.title('Per-class Accuracy', fontsize=14)
        plt.xticks(range(len(class_names)), class_names, rotation=45)
        plt.grid(True, alpha=0.3)

    # 16. Training Stability - Rolling Standard Deviation
    plt.subplot(5, 4, 19)
    window_size = 3
    rolling_train_std = []
    rolling_val_std = []

    for i in range(len(history['train_loss'])):
        start_idx = max(0, i - window_size + 1)
        end_idx = i + 1
        train_window = history['train_loss'][start_idx:end_idx]
        val_window = history['val_loss'][start_idx:end_idx]

        rolling_train_std.append(np.std(train_window))
        rolling_val_std.append(np.std(val_window))

    plt.plot(range(1, len(rolling_train_std) + 1), rolling_train_std, '-', 
             label='Train Loss Std', linewidth=2)
    plt.plot(range(1, len(rolling_val_std) + 1), rolling_val_std, '-', 
             label='Val Loss Std', linewidth=2)
    plt.xlabel('Epoch')
    plt.ylabel('Loss Std Dev')
    plt.title('Training Stability (Rolling Std)')
    plt.legend()
    plt.grid(True, alpha=0.3)

    # 17. Epoch-wise Performance Summary
    plt.subplot(5, 4, 20)
    performance_score = [(acc + f1) / 2 for acc, f1 in zip(history['val_acc'], history['val_f1'])]
    plt.plot(range(1, len(performance_score) + 1), performance_score, linewidth=3)
    plt.xlabel('Epoch')
    plt.ylabel('Combined Performance Score')
    plt.title('Overall Performance Trend', fontsize=14)
    plt.grid(True, alpha=0.3)

    # Mark best epoch
    best_epoch = int(np.argmax(performance_score) + 1)
    plt.axvline(x=best_epoch, linestyle='--', alpha=0.7)
    plt.text(best_epoch, max(performance_score), f'Best: {best_epoch}', 
             rotation=90, verticalalignment='bottom')

    plt.tight_layout()
    plt.savefig('comprehensive_training_results.png', dpi=300, bbox_inches='tight')
    plt.show()


# Main execution
if __name__ == "__main__":
    # Prepare data
    train_loader, val_loader, test_loader, class_names = prepare_data()

    # Setup model
    model = setup_model(len(class_names))
    print(f"\nModel has {sum(p.numel() for p in model.parameters() if p.requires_grad)} trainable parameters")

    # Train model
    print("\nStarting training...")
    history, val_preds, val_labels = train_model(model, train_loader, val_loader)

    # Evaluate on test set
    print("\nEvaluating on test set...")
    test_preds, test_labels, test_probs = get_predictions_with_probabilities(model, test_loader)

    # Plot comprehensive results
    print("\nGenerating visualizations...")
    plot_comprehensive_results(history, class_names, val_preds, val_labels, test_preds, test_labels, test_probs)

    # Save model
    torch.save(model.state_dict(), 'final_alexnet_model.pth')
    print("\nTraining completed and model saved as final_alexnet_model.pth!")
# Out:
# Using device: cuda
#
# Class distribution:
# Train: [4761 3176]
# Val: [1020  681]
# Test: [1021  681]
# C:\Users\acer\AppData\Local\Programs\Python\Python39\lib\site-packages\torch\optim\lr_scheduler.py:62: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(
# Model has 56017410 trainable parameters
#
# Starting training...
# Epoch 1/20 - Training: 100%|█████████████████████████████████████████████████████████| 497/497 [01:28<00:00,  5.62it/s]
# Evaluating: 100%|████████████████████████████████████████████████████████████████████| 107/107 [00:25<00:00,  4.24it/s]
# Epoch 1: Train Loss: 0.5103 | Val Loss: 0.4150 | Train Acc: 0.7415 | Val Acc: 0.8113
#          Train F1: 0.7371 | Val F1: 0.8131 | LR: 0.000050
# Epoch 2/20 - Training: 100%|█████████████████████████████████████████████████████████| 497/497 [01:25<00:00,  5.81it/s]
# Evaluating: 100%|████████████████████████████████████████████████████████████████████| 107/107 [00:24<00:00,  4.34it/s]
# Epoch 2: Train Loss: 0.3676 | Val Loss: 0.3921 | Train Acc: 0.8351 | Val Acc: 0.8424
#          Train F1: 0.8339 | Val F1: 0.8440 | LR: 0.000050
# Epoch 3/20 - Training: 100%|█████████████████████████████████████████████████████████| 497/497 [01:27<00:00,  5.65it/s]
# Evaluating: 100%|████████████████████████████████████████████████████████████████████| 107/107 [00:25<00:00,  4.25it/s]
# Epoch 3: Train Loss: 0.3002 | Val Loss: 0.3733 | Train Acc: 0.8743 | Val Acc: 0.8295
#          Train F1: 0.8736 | Val F1: 0.8309 | LR: 0.000050
# Epoch 4/20 - Training: 100%|█████████████████████████████████████████████████████████| 497/497 [01:27<00:00,  5.67it/s]
# Evaluating: 100%|████████████████████████████████████████████████████████████████████| 107/107 [00:24<00:00,  4.33it/s]
# Epoch 4: Train Loss: 0.2530 | Val Loss: 0.2170 | Train Acc: 0.8944 | Val Acc: 0.9112
#          Train F1: 0.8940 | Val F1: 0.9117 | LR: 0.000050
# Epoch 5/20 - Training: 100%|█████████████████████████████████████████████████████████| 497/497 [01:32<00:00,  5.39it/s]
# Evaluating: 100%|████████████████████████████████████████████████████████████████████| 107/107 [00:24<00:00,  4.32it/s]
# Epoch 5: Train Loss: 0.2158 | Val Loss: 0.2161 | Train Acc: 0.9110 | Val Acc: 0.9118
#          Train F1: 0.9109 | Val F1: 0.9125 | LR: 0.000050
# Epoch 6/20 - Training: 100%|█████████████████████████████████████████████████████████| 497/497 [01:27<00:00,  5.66it/s]
# Evaluating: 100%|████████████████████████████████████████████████████████████████████| 107/107 [00:27<00:00,  3.96it/s]
# Epoch 6: Train Loss: 0.1857 | Val Loss: 0.1360 | Train Acc: 0.9223 | Val Acc: 0.9447
#          Train F1: 0.9221 | Val F1: 0.9449 | LR: 0.000050
# Epoch 7/20 - Training: 100%|█████████████████████████████████████████████████████████| 497/497 [01:28<00:00,  5.60it/s]
# Evaluating: 100%|████████████████████████████████████████████████████████████████████| 107/107 [00:25<00:00,  4.15it/s]
# Epoch 7: Train Loss: 0.1711 | Val Loss: 0.1648 | Train Acc: 0.9321 | Val Acc: 0.9347
#          Train F1: 0.9320 | Val F1: 0.9352 | LR: 0.000050
# Epoch 8/20 - Training: 100%|█████████████████████████████████████████████████████████| 497/497 [01:29<00:00,  5.58it/s]
# Evaluating: 100%|████████████████████████████████████████████████████████████████████| 107/107 [00:25<00:00,  4.13it/s]
# Epoch 8: Train Loss: 0.1558 | Val Loss: 0.1243 | Train Acc: 0.9359 | Val Acc: 0.9518
#          Train F1: 0.9358 | Val F1: 0.9520 | LR: 0.000050
# Epoch 9/20 - Training: 100%|█████████████████████████████████████████████████████████| 497/497 [01:27<00:00,  5.68it/s]
# Evaluating: 100%|████████████████████████████████████████████████████████████████████| 107/107 [00:25<00:00,  4.12it/s]
# Epoch 9: Train Loss: 0.1408 | Val Loss: 0.0937 | Train Acc: 0.9428 | Val Acc: 0.9706
#          Train F1: 0.9428 | Val F1: 0.9707 | LR: 0.000050
# Epoch 10/20 - Training: 100%|████████████████████████████████████████████████████████| 497/497 [01:29<00:00,  5.56it/s]
# Evaluating: 100%|████████████████████████████████████████████████████████████████████| 107/107 [00:25<00:00,  4.14it/s]
# Epoch 10: Train Loss: 0.1334 | Val Loss: 0.0881 | Train Acc: 0.9481 | Val Acc: 0.9688
#          Train F1: 0.9480 | Val F1: 0.9689 | LR: 0.000050
# Epoch 11/20 - Training: 100%|████████████████████████████████████████████████████████| 497/497 [01:27<00:00,  5.70it/s]
# Evaluating: 100%|████████████████████████████████████████████████████████████████████| 107/107 [00:25<00:00,  4.15it/s]
# Epoch 11: Train Loss: 0.1143 | Val Loss: 0.1030 | Train Acc: 0.9540 | Val Acc: 0.9606
#          Train F1: 0.9540 | Val F1: 0.9606 | LR: 0.000050
# Epoch 12/20 - Training: 100%|████████████████████████████████████████████████████████| 497/497 [01:28<00:00,  5.60it/s]
# Evaluating: 100%|████████████████████████████████████████████████████████████████████| 107/107 [00:25<00:00,  4.12it/s]
# Epoch 12: Train Loss: 0.1125 | Val Loss: 0.1041 | Train Acc: 0.9569 | Val Acc: 0.9588
#          Train F1: 0.9569 | Val F1: 0.9589 | LR: 0.000050
# Epoch 13/20 - Training: 100%|████████████████████████████████████████████████████████| 497/497 [01:29<00:00,  5.58it/s]
# Evaluating: 100%|████████████████████████████████████████████████████████████████████| 107/107 [00:25<00:00,  4.20it/s]
# Epoch 13: Train Loss: 0.1144 | Val Loss: 0.0906 | Train Acc: 0.9573 | Val Acc: 0.9694
#          Train F1: 0.9573 | Val F1: 0.9696 | LR: 0.000005
# Epoch 14/20 - Training: 100%|████████████████████████████████████████████████████████| 497/497 [01:28<00:00,  5.61it/s]
# Evaluating: 100%|████████████████████████████████████████████████████████████████████| 107/107 [00:24<00:00,  4.33it/s]
# Epoch 14: Train Loss: 0.0825 | Val Loss: 0.0609 | Train Acc: 0.9690 | Val Acc: 0.9806
#          Train F1: 0.9690 | Val F1: 0.9806 | LR: 0.000005
# Epoch 15/20 - Training: 100%|████████████████████████████████████████████████████████| 497/497 [01:23<00:00,  5.92it/s]
# Evaluating: 100%|████████████████████████████████████████████████████████████████████| 107/107 [00:24<00:00,  4.35it/s]
# Epoch 15: Train Loss: 0.0716 | Val Loss: 0.0573 | Train Acc: 0.9720 | Val Acc: 0.9830
#          Train F1: 0.9720 | Val F1: 0.9830 | LR: 0.000005
# Epoch 16/20 - Training: 100%|████████████████████████████████████████████████████████| 497/497 [01:26<00:00,  5.73it/s]
# Evaluating: 100%|████████████████████████████████████████████████████████████████████| 107/107 [00:24<00:00,  4.39it/s]
# Epoch 16: Train Loss: 0.0658 | Val Loss: 0.0656 | Train Acc: 0.9748 | Val Acc: 0.9800
#          Train F1: 0.9748 | Val F1: 0.9801 | LR: 0.000005
# Epoch 17/20 - Training: 100%|████████████████████████████████████████████████████████| 497/497 [01:26<00:00,  5.76it/s]
# Evaluating: 100%|████████████████████████████████████████████████████████████████████| 107/107 [00:26<00:00,  4.04it/s]
# Epoch 17: Train Loss: 0.0656 | Val Loss: 0.0592 | Train Acc: 0.9743 | Val Acc: 0.9818
#          Train F1: 0.9743 | Val F1: 0.9818 | LR: 0.000005
# Epoch 18/20 - Training: 100%|████████████████████████████████████████████████████████| 497/497 [01:30<00:00,  5.49it/s]
# Evaluating: 100%|████████████████████████████████████████████████████████████████████| 107/107 [00:27<00:00,  3.94it/s]
# Epoch 18: Train Loss: 0.0683 | Val Loss: 0.0489 | Train Acc: 0.9749 | Val Acc: 0.9847
#          Train F1: 0.9749 | Val F1: 0.9847 | LR: 0.000005
# Epoch 19/20 - Training: 100%|████████████████████████████████████████████████████████| 497/497 [01:33<00:00,  5.29it/s]
# Evaluating: 100%|████████████████████████████████████████████████████████████████████| 107/107 [00:25<00:00,  4.21it/s]
# Epoch 19: Train Loss: 0.0699 | Val Loss: 0.0515 | Train Acc: 0.9735 | Val Acc: 0.9841
#          Train F1: 0.9735 | Val F1: 0.9841 | LR: 0.000005
# Epoch 20/20 - Training: 100%|████████████████████████████████████████████████████████| 497/497 [01:28<00:00,  5.59it/s]
# Evaluating: 100%|████████████████████████████████████████████████████████████████████| 107/107 [00:26<00:00,  4.07it/s]
# Epoch 20: Train Loss: 0.0657 | Val Loss: 0.0484 | Train Acc: 0.9751 | Val Acc: 0.9853
#          Train F1: 0.9750 | Val F1: 0.9853 | LR: 0.000005
#
# Evaluating on test set...
# Getting predictions with probabilities: 100%|████████████████████████████████████████| 107/107 [00:27<00:00,  3.87it/s]
# Generating visualizations...
# Training completed and model saved as final_alexnet_model.pth!
